# %%
import random, re, math
from pathlib import Path
from typing import List, Dict, Tuple
from collections import Counter
import numpy as np
import pandas as pd

# %% [markdown]
# # 0. Data Preprocessing

# %%
token = re.compile(r"[A-Za-z][A-Za-z0-9_']+")

# %%
def strip_first4(text: str) -> str:
    lines = text.splitlines()
    return "\n".join(lines[4:])

# %%
def tokenize(text: str) -> List[str]:
    return [t.lower() for t in token.findall(text)]

# %% [markdown]
# # 1.  Data Refining

# %%
def list_class_files(root: Path) -> List[Tuple[str, Path]]:
    if not root.exists() or not root.is_dir():
        raise ValueError(f"[list_class_files] Not a directory: {root}")
    
    return [
        (d.name, f)
        for d in sorted(p for p in root.iterdir() if p.is_dir())
        for f in sorted(d.iterdir())
        if f.is_file()
    ]

# %%
def stratified_half_split(items: List[Tuple[str, Path]], seed: int = 42):
    rng = random.Random(seed)
    by_cls: Dict[str, List[Path]] = {}
    for c, fp in items:
        by_cls.setdefault(c, []).append(fp)

    train, test = [], []
    for c, files in by_cls.items():
        rng.shuffle(files)
        k = len(files) // 2
        train.extend(files[:k])
        test.extend(files[k:])
    return train, test

# %% [markdown]
# # 2. NB

# %%
def train_naive_bayes(docs: List[List[str]], labels: List[str], stop_top_k: int = 200):
    classes = sorted(set(labels))
    N_doc = len(docs)
    N_c = Counter(labels)
    logprior = {c: math.log(N_c[c] / N_doc + 1e-15) for c in classes}

    bigdoc = {c: Counter() for c in classes}
    for toks, y in zip(docs, labels):
        bigdoc[y].update(toks)

    total_counts = Counter()
    for c in classes:
        total_counts.update(bigdoc[c])

    #V_set = set(total_counts.keys())
    stop_words = set([w for w, _ in total_counts.most_common(stop_top_k)])

    V_set = set(total_counts.keys()) - stop_words
    V_size = len(V_set)

    loglikelihood = {c: {} for c in classes}
    for c in classes:
        total_c = sum(bigdoc[c].values())
        denom_log = math.log(total_c + V_size)
        for w in V_set:
            num = bigdoc[c][w] + 1
            loglikelihood[c][w] = math.log(num) - denom_log
    
    return V_set, logprior, loglikelihood

# %%
def predict_nb(doc_tokens: List[str], Vset, logprior, loglikelihood) -> str:
    tf = Counter([w for w in doc_tokens if w in Vset])
    best_c, best_score = None, float('-inf')
    for c in logprior.keys():
        s = logprior[c]
        llc = loglikelihood[c]
        for w, cnt in tf.items():
            s += cnt * llc[w]
        if s > best_score:
            best_c, best_score = c, s
    
    return best_c

# %%
def predict_many_nb(test_docs: List[List[str]], Vset, logprior, loglikelihood) -> List[str]:
    return [predict_nb(toks, Vset, logprior, loglikelihood) for toks in test_docs]

# %% [markdown]
# # 3. Pipeline

# %%
def load_and_tokenize(paths: List[Path]) -> List[List[str]]:
    docs = []
    for fp in paths:
        try:
            raw = fp.read_text(encoding = "utf-8", errors = "ignore")
        except UnicodeDecodeError:
            raw = fp.read_text(encoding = "latin-1", errors = "ignore")
        body = strip_first4(raw)
        docs.append(tokenize(body))
    
    return docs

# %%
def run_pipeline(root: Path, seed: int):
    items = list_class_files(root)
    train_paths, test_paths = stratified_half_split(items, seed = seed)

    y_train = [p.parent.name for p in train_paths]
    y_test = [p.parent.name for p in test_paths]

    Xtr_tokens = load_and_tokenize(train_paths)
    Xte_tokens = load_and_tokenize(test_paths)

    V_set, logprior, loglikelihood = train_naive_bayes(Xtr_tokens, y_train)
    y_hat = predict_many_nb(Xte_tokens, V_set, logprior, loglikelihood)

    acc = np.mean([predicted == trained for predicted, trained in zip(y_hat, y_test)])
    print(f"[RESULT] Test Accuracy: {acc:.4f}")

    cm = pd.crosstab(pd.Series(y_test, name = "True"),
                     pd.Series(y_hat, name = "Pred"),
                     dropna=False)
    print(cm)

    
    cm.to_csv("confusion_matrix.csv", encoding = "utf-8")
    print("[INFO] Confusion matrix saved to confusion_matrix.csv")


    with open("accuracy.txt", "w", encoding="utf-8") as f:
        f.write(f"{acc:.4f}\n")
    print("[INFO] Accuracy saved to accuracy.txt")

# %%
from pathlib import Path
run_pipeline(Path("/Users/gwaec/umd_lectures_projects/cmsc422/hw1/20_newsgroups"), seed=42)
# Out:
# [RESULT] Test Accuracy: 0.8383
# Pred                      alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# True
# alt.atheism                       410              0                        0
# comp.graphics                       0            434                        1
# comp.os.ms-windows.misc             0             84                      195
# comp.sys.ibm.pc.hardware            1             22                        6
# comp.sys.mac.hardware               1             12                        2
# comp.windows.x                      0             46                        0
# misc.forsale                        1             10                        2
# rec.autos                           2              2                        0
# rec.motorcycles                     0              0                        0
# rec.sport.baseball                  0              1                        1
# rec.sport.hockey                    0              0                        0
# sci.crypt                           0              9                        2
# sci.electronics                     0             27                        0
# sci.med                             1              8                        0
# sci.space                           0              8                        0
# soc.religion.christian              1              0                        0
# talk.politics.guns                  0              0                        0
# talk.politics.mideast               3              1                        0
# talk.politics.misc                  1              1                        0
# talk.religion.misc                120              1                        0
#
# Pred                      comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  \
# True
# alt.atheism                                      0                      0
# comp.graphics                                   17                      3
# comp.os.ms-windows.misc                        126                     20
# comp.sys.ibm.pc.hardware                       393                     31
# comp.sys.mac.hardware                           22                    416
# comp.windows.x                                   6                      2
# misc.forsale                                    26                     19
# rec.autos                                        1                      2
# rec.motorcycles                                  0                      0
# rec.sport.baseball                               0                      0
# rec.sport.hockey                                 0                      0
# sci.crypt                                        0                      0
# sci.electronics                                 17                     15
# sci.med                                          2                      1
# sci.space                                        0                      1
# soc.religion.christian                           0                      0
# talk.politics.guns                               1                      0
# talk.politics.mideast                            0                      1
# talk.politics.misc                               0                      0
# talk.religion.misc                               0                      0
#
# Pred                      comp.windows.x  misc.forsale  rec.autos  \
# True
# alt.atheism                            0             0          0
# comp.graphics                         17             8          1
# comp.os.ms-windows.misc               40             3          1
# comp.sys.ibm.pc.hardware               6            19          0
# comp.sys.mac.hardware                  3            11          3
# comp.windows.x                       430             2          1
# misc.forsale                           1           375         21
# rec.autos                              0             8        449
# rec.motorcycles                        0             4          8
# rec.sport.baseball                     1             4          5
# rec.sport.hockey                       0             2          0
# sci.crypt                              1             2          1
# sci.electronics                        3             4          7
# sci.med                                1             2          1
# sci.space                              1             1          0
# soc.religion.christian                 1             0          0
# talk.politics.guns                     0             0          2
# talk.politics.mideast                  0             0          1
# talk.politics.misc                     0             0          1
# talk.religion.misc                     0             0          0
#
# Pred                      rec.motorcycles  rec.sport.baseball  \
# True
# alt.atheism                             1                   0
# comp.graphics                           2                   2
# comp.os.ms-windows.misc                 1                   3
# comp.sys.ibm.pc.hardware                0                   0
# comp.sys.mac.hardware                   3                   4
# comp.windows.x                          3                   1
# misc.forsale                            4                   3
# rec.autos                              11                   1
# rec.motorcycles                       469                   1
# rec.sport.baseball                      0                 467
# rec.sport.hockey                        2                   6
# sci.crypt                               0                   1
# sci.electronics                         2                   0
# sci.med                                 1                   1
# sci.space                               0                   1
# soc.religion.christian                  0                   0
# talk.politics.guns                      0                   0
# talk.politics.mideast                   0                   1
# talk.politics.misc                      0                   1
# talk.religion.misc                      0                   0
#
# Pred                      rec.sport.hockey  sci.crypt  sci.electronics  \
# True
# alt.atheism                              1          1                1
# comp.graphics                            0          2                3
# comp.os.ms-windows.misc                  1          3                6
# comp.sys.ibm.pc.hardware                 3          4               11
# comp.sys.mac.hardware                    2          3                8
# comp.windows.x                           0          2                1
# misc.forsale                             4          2               11
# rec.autos                                1          1                5
# rec.motorcycles                          2          0                3
# rec.sport.baseball                      11          0                3
# rec.sport.hockey                       488          0                0
# sci.crypt                                1        477                0
# sci.electronics                          4          9              394
# sci.med                                  2          2                5
# sci.space                                0          3                1
# soc.religion.christian                   0          0                0
# talk.politics.guns                       0          3                1
# talk.politics.mideast                    2          1                0
# talk.politics.misc                       0          4                0
# talk.religion.misc                       2          0                1
#
# Pred                      sci.med  sci.space  soc.religion.christian  \
# True
# alt.atheism                     3          0                       3
# comp.graphics                   2          4                       0
# comp.os.ms-windows.misc         3          9                       0
# comp.sys.ibm.pc.hardware        0          2                       0
# comp.sys.mac.hardware           2          6                       0
# comp.windows.x                  0          6                       0
# misc.forsale                    6          4                       0
# rec.autos                       0          4                       0
# rec.motorcycles                 1          5                       0
# rec.sport.baseball              0          4                       0
# rec.sport.hockey                0          0                       0
# sci.crypt                       2          0                       0
# sci.electronics                 3         13                       0
# sci.med                       461          4                       0
# sci.space                       1        478                       0
# soc.religion.christian          2          0                     488
# talk.politics.guns              1          2                       0
# talk.politics.mideast           1          0                       0
# talk.politics.misc              0          5                       0
# talk.religion.misc              3          4                      22
#
# Pred                      talk.politics.guns  talk.politics.mideast  \
# True
# alt.atheism                                0                      3
# comp.graphics                              1                      2
# comp.os.ms-windows.misc                    2                      0
# comp.sys.ibm.pc.hardware                   1                      1
# comp.sys.mac.hardware                      0                      0
# comp.windows.x                             0                      0
# misc.forsale                               3                      1
# rec.autos                                  5                      1
# rec.motorcycles                            1                      3
# rec.sport.baseball                         2                      0
# rec.sport.hockey                           0                      0
# sci.crypt                                  3                      0
# sci.electronics                            2                      0
# sci.med                                    5                      1
# sci.space                                  3                      0
# soc.religion.christian                     0                      4
# talk.politics.guns                       459                      5
# talk.politics.mideast                      1                    476
# talk.politics.misc                        41                     31
# talk.religion.misc                        36                      4
#
# Pred                      talk.politics.misc  talk.religion.misc
# True
# alt.atheism                                3                  74
# comp.graphics                              1                   0
# comp.os.ms-windows.misc                    3                   0
# comp.sys.ibm.pc.hardware                   0                   0
# comp.sys.mac.hardware                      1                   1
# comp.windows.x                             0                   0
# misc.forsale                               6                   1
# rec.autos                                  6                   1
# rec.motorcycles                            3                   0
# rec.sport.baseball                         0                   1
# rec.sport.hockey                           2                   0
# sci.crypt                                  1                   0
# sci.electronics                            0                   0
# sci.med                                    2                   0
# sci.space                                  1                   1
# soc.religion.christian                     2                   1
# talk.politics.guns                        24                   2
# talk.politics.mideast                     11                   1
# talk.politics.misc                       378                  37
# talk.religion.misc                        62                 245
# [INFO] Confusion matrix saved to confusion_matrix.csv
# [INFO] Accuracy saved to accuracy.txt
